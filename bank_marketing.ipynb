# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/bank_customers_train.csv.zip")
df
# Out:
#        age          job   marital          education default housing loan  \
# 0       35  blue-collar    single        high.school     NaN      no   no
# 1       52  blue-collar   married                NaN     NaN     yes   no
# 2       38     services   married        high.school     NaN      no   no
# 3       44       admin.   married  university.degree      no     yes   no
# 4       25     services  divorced           basic.4y      no     yes   no
# ...    ...          ...       ...                ...     ...     ...  ...
# 39183   43       admin.    single  university.degree      no      no   no
# 39184   31       admin.   married        high.school      no      no   no
# 39185   49  blue-collar   married           basic.4y     NaN      no   no
# 39186   31       admin.    single  university.degree      no     yes   no
# 39187   43  blue-collar   married           basic.9y      no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0       cellular   jul         thu  ...         3    999         0
# 1      telephone   jun         thu  ...         4    999         0
# 2      telephone   jun         tue  ...         2    999         0
# 3      telephone   oct         wed  ...         1    999         0
# 4      telephone   may         fri  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 39183   cellular   may         tue  ...         1    999         0
# 39184   cellular   apr         fri  ...         2    999         0
# 39185  telephone   jun         fri  ...         1    999         0
# 39186  telephone   jun         wed  ...         1    999         0
# 39187  telephone   jun         tue  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.4          93.918          -42.7      4.958
# 1      nonexistent          1.4          94.465          -41.8      4.961
# 2      nonexistent          1.4          94.465          -41.8      4.864
# 3      nonexistent         -3.4          92.431          -26.9      0.735
# 4      nonexistent          1.1          93.994          -36.4      4.859
# ...            ...          ...             ...            ...        ...
# 39183  nonexistent         -1.8          92.893          -46.2      1.291
# 39184  nonexistent         -1.8          93.075          -47.1      1.405
# 39185  nonexistent          1.4          94.465          -41.8      4.959
# 39186  nonexistent          1.4          94.465          -41.8      4.959
# 39187  nonexistent          1.4          94.465          -41.8      4.961
#
#        nr.employed    y
# 0           5228.1   no
# 1           5228.1   no
# 2           5228.1   no
# 3           5017.5  yes
# 4           5191.0   no
# ...            ...  ...
# 39183       5099.1   no
# 39184       5099.1   no
# 39185       5228.1  yes
# 39186       5228.1   no
# 39187       5228.1   no
#
# [39188 rows x 21 columns]

# %%
df.head()
# Out:
#    age          job   marital          education default housing loan  \
# 0   35  blue-collar    single        high.school     NaN      no   no
# 1   52  blue-collar   married                NaN     NaN     yes   no
# 2   38     services   married        high.school     NaN      no   no
# 3   44       admin.   married  university.degree      no     yes   no
# 4   25     services  divorced           basic.4y      no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   jul         thu  ...         3    999         0  nonexistent
# 1  telephone   jun         thu  ...         4    999         0  nonexistent
# 2  telephone   jun         tue  ...         2    999         0  nonexistent
# 3  telephone   oct         wed  ...         1    999         0  nonexistent
# 4  telephone   may         fri  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0          1.4          93.918          -42.7      4.958       5228.1   no
# 1          1.4          94.465          -41.8      4.961       5228.1   no
# 2          1.4          94.465          -41.8      4.864       5228.1   no
# 3         -3.4          92.431          -26.9      0.735       5017.5  yes
# 4          1.1          93.994          -36.4      4.859       5191.0   no
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#        age          job  marital          education default housing loan  \
# 39183   43       admin.   single  university.degree      no      no   no
# 39184   31       admin.  married        high.school      no      no   no
# 39185   49  blue-collar  married           basic.4y     NaN      no   no
# 39186   31       admin.   single  university.degree      no     yes   no
# 39187   43  blue-collar  married           basic.9y      no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 39183   cellular   may         tue  ...         1    999         0
# 39184   cellular   apr         fri  ...         2    999         0
# 39185  telephone   jun         fri  ...         1    999         0
# 39186  telephone   jun         wed  ...         1    999         0
# 39187  telephone   jun         tue  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 39183  nonexistent         -1.8          92.893          -46.2      1.291
# 39184  nonexistent         -1.8          93.075          -47.1      1.405
# 39185  nonexistent          1.4          94.465          -41.8      4.959
# 39186  nonexistent          1.4          94.465          -41.8      4.959
# 39187  nonexistent          1.4          94.465          -41.8      4.961
#
#        nr.employed    y
# 39183       5099.1   no
# 39184       5099.1   no
# 39185       5228.1  yes
# 39186       5228.1   no
# 39187       5228.1   no
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  39188.000000  39188.000000  39188.000000  39188.000000  39188.000000
# mean      39.997754    258.125574      2.568720    962.588394      0.173191
# std       10.407876    258.683120      2.771971    186.631343      0.495921
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    320.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  39188.000000    39188.000000   39188.000000  39188.000000  39188.000000
# mean       0.079787       93.575327     -40.499862      3.618962   5166.920478
# std        1.571619        0.579311       4.631198      1.735424     72.290033
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39188 entries, 0 to 39187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             39188 non-null  int64
#  1   job             38872 non-null  object
#  2   marital         39109 non-null  object
#  3   education       37535 non-null  object
#  4   default         31026 non-null  object
#  5   housing         38248 non-null  object
#  6   loan            38248 non-null  object
#  7   contact         39188 non-null  object
#  8   month           39188 non-null  object
#  9   day_of_week     39188 non-null  object
#  10  duration        39188 non-null  int64
#  11  campaign        39188 non-null  int64
#  12  pdays           39188 non-null  int64
#  13  previous        39188 non-null  int64
#  14  poutcome        39188 non-null  object
#  15  emp.var.rate    39188 non-null  float64
#  16  cons.price.idx  39188 non-null  float64
#  17  cons.conf.idx   39188 non-null  float64
#  18  euribor3m       39188 non-null  float64
#  19  nr.employed     39188 non-null  float64
#  20  y               39188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.3+ MB

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df=df.drop_duplicates()

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (29017, 21)

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
object_columns=df.select_dtypes(include=["object"]).columns.tolist()
for i in object_columns:
   sorted_order=df[i].value_counts().index

   plt.figure(figsize=(10,6))
   ax=sns.countplot(data=df,x=i,palette="hls",order=sorted_order)
   plt.xticks(rotation=90)
   plt.xlabel(i)
   plt.ylabel('Count')
   plt.title(f'bar chart for {i}')
   for p in ax.patches:
     ax.annotate(f'{int(p.get_height())}',(p.get_x()+p.get_width()/2.,p.get_height()))
plt.show()

# %%
object_columns=df.select_dtypes(include=["object"]).columns.tolist()
for i in object_columns:
   sorted_order=df[i].value_counts().index

   plt.figure(figsize=(10,6))
   ax=sns.countplot(data=df,x=i,hue='y',palette="Set1",order=sorted_order)
   plt.xticks(rotation=90)
   plt.xlabel(i)
   plt.ylabel('Count')
   plt.title(f'bar chart for {i} with hue')
   for p in ax.patches:
     ax.annotate(f'{int(p.get_height())}',(p.get_x()+p.get_width()/2.,p.get_height()))
   plt.legend(title='hue',loc='upper right')
   plt.show()

# %%
sns.kdeplot(x=df['age'],fill=True)
mean_age=df["age"].mean()
plt.axvline(mean_age,color='red',linestyle="--",label=f'mean age:(mean_age:.2f)')

plt.xlabel("Age",fontsize=15)
plt.ylabel('Count')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14,loc="upper right")

# %%
num_list=["duration","campaign","pdays","previous","emp.var.rate","cons.price.idx","nr.employed","euribor3m"]
for i in num_list:
  plt.figure(figsize=(6,3))
  df[i].hist(bins=30)
  plt.title(f'{i}')

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29017 entries, 3 to 39187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29017 non-null  int64
#  1   job             29017 non-null  object
#  2   marital         29017 non-null  object
#  3   education       29017 non-null  object
#  4   default         29017 non-null  object
#  5   housing         29017 non-null  object
#  6   loan            29017 non-null  object
#  7   contact         29017 non-null  object
#  8   month           29017 non-null  object
#  9   day_of_week     29017 non-null  object
#  10  duration        29017 non-null  int64
#  11  campaign        29017 non-null  int64
#  12  pdays           29017 non-null  int64
#  13  previous        29017 non-null  int64
#  14  poutcome        29017 non-null  object
#  15  emp.var.rate    29017 non-null  float64
#  16  cons.price.idx  29017 non-null  float64
#  17  cons.conf.idx   29017 non-null  float64
#  18  euribor3m       29017 non-null  float64
#  19  nr.employed     29017 non-null  float64
#  20  y               29017 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 4.9+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29017 entries, 3 to 39187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29017 non-null  int64
#  1   job             29017 non-null  object
#  2   marital         29017 non-null  object
#  3   education       29017 non-null  object
#  4   default         29017 non-null  object
#  5   housing         29017 non-null  object
#  6   loan            29017 non-null  object
#  7   contact         29017 non-null  object
#  8   month           29017 non-null  object
#  9   day_of_week     29017 non-null  object
#  10  duration        29017 non-null  int64
#  11  campaign        29017 non-null  int64
#  12  pdays           29017 non-null  int64
#  13  previous        29017 non-null  int64
#  14  poutcome        29017 non-null  object
#  15  emp.var.rate    29017 non-null  float64
#  16  cons.price.idx  29017 non-null  float64
#  17  cons.conf.idx   29017 non-null  float64
#  18  euribor3m       29017 non-null  float64
#  19  nr.employed     29017 non-null  float64
#  20  y               29017 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 4.9+ MB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
for column in ["job","marital","education","default","housing","loan","contact","month","day_of_week","poutcome"]:
    df[column]=label_encoder.fit_transform(df[column])
df.drop(["day_of_week"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29017 entries, 3 to 39187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29017 non-null  int64
#  1   job             29017 non-null  int64
#  2   marital         29017 non-null  int64
#  3   education       29017 non-null  int64
#  4   default         29017 non-null  int64
#  5   housing         29017 non-null  int64
#  6   loan            29017 non-null  int64
#  7   contact         29017 non-null  int64
#  8   month           29017 non-null  int64
#  9   duration        29017 non-null  int64
#  10  campaign        29017 non-null  int64
#  11  pdays           29017 non-null  int64
#  12  previous        29017 non-null  int64
#  13  poutcome        29017 non-null  int64
#  14  emp.var.rate    29017 non-null  float64
#  15  cons.price.idx  29017 non-null  float64
#  16  cons.conf.idx   29017 non-null  float64
#  17  euribor3m       29017 non-null  float64
#  18  nr.employed     29017 non-null  float64
#  19  y               29017 non-null  object
# dtypes: float64(5), int64(14), object(1)
# memory usage: 4.6+ MB

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap="mako",linecolor="black",linewidth=2,fmt=".0%")
plt.show()
# Out:
# <ipython-input-109-985920a9e133>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="mako",linecolor="black",linewidth=2,fmt=".0%")

# %%
plt.figure(figsize=(10,6))
label_count=df["y"].value_counts().values
label=df["y"].value_counts().index

plt.subplot(1,2,1)
explode=(0,0.2)
colors=["orange","green"]
labels=["No","Yes"]
plt.pie(x=label_count,labels=labels,autopct="%1.1f%%",shadow=True,radius=1,colors=colors,explode=explode)
plt.title("survival distribution")


plt.subplot(1,2,2)
colors=["orange","green"]
sns.countplot(x=df["y"],palette=colors)
plt.xticks([0,1],["No","Yes"])
plt.title("y_count")

plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
x=df.iloc[:,:-1]
x
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 3       44    0        1          6        0        1     0        1      8
# 4       25    7        0          0        0        1     0        1      6
# 5       49    7        1          3        0        0     0        0      1
# 6       30    9        0          3        0        1     1        1      4
# 7       38    1        1          1        0        1     0        0      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 39182   47    1        1          2        0        1     0        0      1
# 39183   43    0        2          6        0        0     0        0      6
# 39184   31    0        1          3        0        0     0        0      0
# 39186   31    0        2          6        0        1     0        1      4
# 39187   43    1        1          2        0        1     0        1      4
#
#        duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 3           749         1    999         0         1          -3.4
# 4           601         1    999         0         1           1.1
# 5           565         1    999         0         1           1.4
# 6           131         2    999         0         1           1.4
# 7           135         2    999         0         1          -1.8
# ...         ...       ...    ...       ...       ...           ...
# 39182       384         1    999         0         1           1.4
# 39183       107         1    999         0         1          -1.8
# 39184       246         2    999         0         1          -1.8
# 39186        76         1    999         0         1           1.4
# 39187       128         1    999         0         1           1.4
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 3              92.431          -26.9      0.735       5017.5
# 4              93.994          -36.4      4.859       5191.0
# 5              93.444          -36.1      4.965       5228.1
# 6              94.465          -41.8      4.961       5228.1
# 7              92.893          -46.2      1.299       5099.1
# ...               ...            ...        ...          ...
# 39182          93.444          -36.1      4.967       5228.1
# 39183          92.893          -46.2      1.291       5099.1
# 39184          93.075          -47.1      1.405       5099.1
# 39186          94.465          -41.8      4.959       5228.1
# 39187          94.465          -41.8      4.961       5228.1
#
# [29017 rows x 19 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 3        yes
# 4         no
# 5         no
# 6         no
# 7         no
#         ...
# 39182     no
# 39183     no
# 39184     no
# 39186     no
# 39187     no
# Name: y, Length: 29017, dtype: object

# %%
from imblearn.over_sampling import SMOTE
x_resample,y_resample=SMOTE().fit_resample(x,y)

# %%
colors=["green","yellow"]
sns.countplot(x=y_resample,palette=colors)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_resample,y_resample,test_size=0.30,random_state=42)
x_train
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 15747   33    1        1          2        0        1     0        0      0
# 48598   38    0        1          3        0        0     0        0      7
# 14885   40    0        1          3        0        1     0        1      4
# 48737   42    0        1          0        0        0     0        0      2
# 6025    30    9        2          6        0        0     1        0      1
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 11284   35    9        2          6        0        1     0        0      1
# 44732   28    0        2          6        0        0     0        0      5
# 38158   32    0        1          5        0        0     0        0      3
# 860     31    1        2          3        0        0     0        0      7
# 15795   44    1        1          2        0        0     0        0      0
#
#        duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 15747       827         1    999         1         0          -1.8
# 48598       245         2    999         0         1          -1.1
# 14885       406         3    999         0         1           1.4
# 48737       961         4    999         0         1           1.4
# 6025         81         2    999         0         1           1.4
# ...         ...       ...    ...       ...       ...           ...
# 11284       159         1    999         0         1           1.4
# 44732       234         2    999         0         0          -1.8
# 38158       253         1    999         0         1          -2.9
# 860         184         1    999         0         1          -0.1
# 15795         1         1    999         0         1          -1.8
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 15747       93.075000     -47.100000   1.410000       5099.1
# 48598       94.767000     -50.800000   1.042823       4963.6
# 14885       94.465000     -41.800000   4.864000       5228.1
# 48737       93.863095     -41.935501   4.963232       5228.1
# 6025        93.444000     -36.100000   4.964000       5228.1
# ...               ...            ...        ...          ...
# 11284       93.444000     -36.100000   4.968000       5228.1
# 44732       93.693655     -38.129800   0.658693       5008.7
# 38158       92.958017     -40.727370   1.263761       5076.2
# 860         93.200000     -42.000000   4.076000       5195.8
# 15795       93.075000     -47.100000   1.453000       5099.1
#
# [35488 rows x 19 columns]

# %%
x_test
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 33534   71    4        1          0        0        0     1        0      3
# 3104    42    4        1          6        0        1     1        0      7
# 28364   44    1        1          2        0        0     0        1      4
# 26656   37    9        0          5        0        0     0        0      1
# 17596   41    7        1          3        0        0     0        1      4
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 47921   41    0        1          3        0        1     0        0      8
# 13810   34    4        2          6        0        1     0        1      6
# 49295   37    3        1          5        0        0     0        0      2
# 10159   47    0        1          2        0        1     0        1      7
# 50467   28    8        2          4        0        0     0        1      3
#
#        duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 33534       481         4      7         1         2     -1.707681
# 3104        128         1    999         0         1     -0.100000
# 28364       109         4    999         0         1      1.400000
# 26656       312         1    999         0         1      1.400000
# 17596       366         1    999         0         1      1.400000
# ...         ...       ...    ...       ...       ...           ...
# 47921       211         1    999         0         0     -3.400000
# 13810        18         1    999         0         1     -1.800000
# 49295       293         1     10         1         2     -1.700000
# 10159        64         3    999         0         1     -0.100000
# 50467       420         1      6         2         2     -1.700000
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 33534       94.188960     -40.276956   0.811400  4992.913506
# 3104        93.200000     -42.000000   4.191000  5195.800000
# 28364       94.465000     -41.800000   4.959000  5228.100000
# 26656       93.444000     -36.100000   4.965000  5228.100000
# 17596       94.465000     -41.800000   4.864000  5228.100000
# ...               ...            ...        ...          ...
# 47921       92.446112     -29.874568   0.758583  5017.500000
# 13810       93.876000     -40.000000   0.683000  5008.700000
# 49295       94.044013     -39.211390   0.790241  4991.600000
# 10159       93.200000     -42.000000   4.021000  5195.800000
# 50467       94.215000     -40.300000   0.869057  4991.600000
#
# [15210 rows x 19 columns]

# %%
y_train
# Out:
# 15747     no
# 48598    yes
# 14885     no
# 48737    yes
# 6025      no
#         ...
# 11284     no
# 44732    yes
# 38158    yes
# 860       no
# 15795     no
# Name: y, Length: 35488, dtype: object

# %%
y_test
# Out:
# 33534    yes
# 3104      no
# 28364     no
# 26656     no
# 17596     no
#         ...
# 47921    yes
# 13810     no
# 49295    yes
# 10159     no
# 50467    yes
# Name: y, Length: 15210, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-0.55516287, -0.75884373, -0.18899854, ..., -1.26594181,
#         -0.74907501, -0.34790979],
#        [-0.10796388, -1.05328771, -0.18899854, ..., -1.94960194,
#         -0.94468338, -1.9013671 ],
#        [ 0.07091572, -1.05328771, -0.18899854, ..., -0.28664488,
#          1.0909927 ,  1.13102742],
#        ...,
#        [-0.64460267, -1.05328771, -0.18899854, ..., -0.08845182,
#         -0.82698191, -0.61044981],
#        [-0.73404247, -0.75884373,  1.43148474, ..., -0.32359948,
#          0.67119729,  0.76071989],
#        [ 0.42867491, -0.75884373, -0.18899854, ..., -1.26594181,
#         -0.72616739, -0.34790979]])

# %%
x_test
# Out:
# array([[ 2.84354947,  0.12448821, -0.18899854, ..., -0.00522747,
#         -1.06797048, -1.56529861],
#        [ 0.24979532,  0.12448821, -0.18899854, ..., -0.32359948,
#          0.73246184,  0.76071989],
#        [ 0.42867491, -0.75884373, -0.18899854, ..., -0.28664488,
#          1.14160255,  1.13102742],
#        ...,
#        [-0.19740368, -0.16995577, -0.18899854, ...,  0.19166046,
#         -1.07924258, -1.58035747],
#        [ 0.69699431, -1.05328771, -0.18899854, ..., -0.32359948,
#          0.64189684,  0.76071989],
#        [-1.00236186,  1.30226412,  1.43148474, ..., -0.00948537,
#         -1.0372542 , -1.58035747]])

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['yes', 'no', 'no', ..., 'yes', 'no', 'yes'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
accuracy=accuracy_score(y_test,y_pred)
print("decision tree",accuracy)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# decision tree 0.9168310322156475
#               precision    recall  f1-score   support
#
#           no       0.92      0.91      0.92      7570
#          yes       0.91      0.92      0.92      7640
#
#     accuracy                           0.92     15210
#    macro avg       0.92      0.92      0.92     15210
# weighted avg       0.92      0.92      0.92     15210
#
# [[6887  683]
#  [ 582 7058]]
